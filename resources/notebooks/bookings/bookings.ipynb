# %%
dbutils.widgets.text("catalog", "")

catalog = dbutils.widgets.get("catalog")

tabela = "samples.wanderbricks.bookings"

df = spark.table(tabela)

df.write.mode("overwrite").saveAsTable(f"{catalog}.default.bookings")
